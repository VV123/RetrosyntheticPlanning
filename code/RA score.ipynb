# %%
# !pip install wandb -qU
# Out:
#      |████████████████████████████████| 1.9 MB 6.0 MB/s
#      |████████████████████████████████| 182 kB 45.6 MB/s
#      |████████████████████████████████| 168 kB 35.6 MB/s
#      |████████████████████████████████| 62 kB 1.1 MB/s
#      |████████████████████████████████| 168 kB 67.2 MB/s
#      |████████████████████████████████| 166 kB 65.8 MB/s
#      |████████████████████████████████| 166 kB 66.0 MB/s
#      |████████████████████████████████| 162 kB 57.1 MB/s
#      |████████████████████████████████| 162 kB 52.9 MB/s
#      |████████████████████████████████| 158 kB 68.6 MB/s
#      |████████████████████████████████| 157 kB 58.8 MB/s
#      |████████████████████████████████| 157 kB 47.1 MB/s
#      |████████████████████████████████| 157 kB 56.7 MB/s
#      |████████████████████████████████| 157 kB 49.5 MB/s
#      |████████████████████████████████| 157 kB 39.5 MB/s
#      |████████████████████████████████| 157 kB 74.9 MB/s
#      |████████████████████████████████| 157 kB 51.2 MB/s
# ...

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !pip install rdkit-pypi -qqq
# Out:
#      |████████████████████████████████| 29.3 MB 1.3 MB/s

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls ./gdrive
# Out:
# Mounted at /content/gdrive
# MyDrive

# %%
from rdkit import Chem
from rdkit.Chem import RDConfig
from rdkit.Chem import rdMolDescriptors
import pickle
import sys
import time
import math
from collections import defaultdict
import os
import json
import gzip
import six
import pandas as pd
import csv

sys.stdout = open(os.devnull, "w")
sys.stderr = open(os.devnull, "w")

sys.path.append(os.path.join(RDConfig.RDContribDir, '/content/gdrive/MyDrive/RAscore-master/'))
# now you can import RAscore!

from RAscore import RAscore_NN

nn_scorer = RAscore_NN.RAScorerNN() 

sys.stdout = sys.__stdout__
sys.stderr = sys.__stderr__

with open('/content/gdrive/MyDrive/scscore-master/positive_chembl.csv', 'r', encoding="utf-8") as f:

  input_variable = []
  for row in f:
    sco = nn_scorer.predict(row)
    input_variable.append(['%.4f , %s' % (sco, row)])

with open ('/content/gdrive/MyDrive/RAscore-master/ChEMBLE_RA_test_result.csv','a',newline = '') as csvfile:
      my_writer = csv.writer(csvfile, delimiter = ' ')
      my_writer.writerows(input_variable)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
